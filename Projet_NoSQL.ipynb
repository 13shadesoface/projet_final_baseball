# %% [markdown]
# # Tests d'API

# %%
import http.client

conn = http.client.HTTPSConnection("mlb-data.p.rapidapi.com")

headers = {
    'X-RapidAPI-Host': "mlb-data.p.rapidapi.com",
    'X-RapidAPI-Key': "9ad2d0a85cmsh1932113a0fbc116p1dfd43jsnd616bcbbd627"
    }

conn.request("GET", "/json/named.player_teams.bam?player_id='493316'&season='2014'", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"player_teams":{"copyRight":" NOTICE: This file is no longer actively supported. Please use the MLB Stats API (http://statsapi.mlb.com/docs/) as an alternative. Copyright 2022 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt  ","queryResults":{"totalSize":"2","created":"2022-06-20T10:08:00","row":[{"end_date":"2014-12-10T00:00:00","sport_id":"1","status_date":"2014-08-01T00:00:00","status_code":"A","league_short":"American","class_id":"1","team_id":"111","sport_full":"Major League Baseball","team_brief":"Red Sox","player_id":"493316","org_short":"Boston","team_short":"Boston","primary_position":"LF","jersey_number":"52","pitching_season":"","org_full":"Boston Red Sox","class":"MLB","start_date":"2014-07-31T00:00:00","hitting_season":"2014","org":"Red Sox","season_state":"offseason","league_full":"American League","league":"AL","forty_man_sw":"Y","league_season":"2014","sport_code":"mlb","team":"Boston Red Sox","org_abbrev":"BOS","sport_short":"","team_abbrev":"BOS","org_id":"111","forty_man_sw_old":"Y","primary_stat_type":"hitting","sport":"MLB","current_sw":"N","fielding_season":"2014","league_id":"103","status":"Active"},{"end_date":"2014-07-31T00:00:00","sport_id":"1","status_date":"2014-07-30T00:00:00","status_code":"TR","league_short":"American","class_id":"1","team_id":"133","sport_full":"Major League Baseball","team_brief":"Athletics","player_id":"493316","org_short":"Oakland","team_short":"Oakland","primary_position":"LF","jersey_number":"52","pitching_season":"","org_full":"Oakland Athletics","class":"MLB","start_date":"2012-03-03T00:00:00","hitting_season":"2014","org":"Athletics","season_state":"offseason","league_full":"American League","league":"AL","forty_man_sw":"Y","league_season":"2014","sport_code":"mlb","team":"Oakland Athletics","org_abbrev":"OAK","sport_short":"","team_abbrev":"OAK","org_id":"133","forty_man_sw_old":"N","primary_stat_type":"hitting","sport":"MLB","current_sw":"N","fielding_season":"2014","league_id":"103","status":"Traded"}]}}}

# %%
import http.client

conn = http.client.HTTPSConnection("api-baseball.p.rapidapi.com")

headers = {
    'X-RapidAPI-Key': "SIGN-UP-FOR-KEY",
    'X-RapidAPI-Host': "api-baseball.p.rapidapi.com"
    }

conn.request("GET", "/teams/statistics?season=2019", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"message":"You are not subscribed to this API."}

# %% [markdown]
# # CRUD

# %%
from pymongo import MongoClient
client = MongoClient("mongodb://nosql:<nosql>@cluster0.sbfna1n.mongodb.net/?retryWrites=true&w=majority")
db = client.baseball

# %%
manager = db["manager"]
print(manager.find_one())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-f1a4d897e036> in <module>()
#       1 manager = db["manager"]
# ----> 2 print(manager.find_one())
#
# /usr/local/lib/python3.7/dist-packages/pymongo/collection.py in find_one(self, filter, *args, **kwargs)
#    1417             filter = {"_id": filter}
#    1418         cursor = self.find(filter, *args, **kwargs)
# -> 1419         for result in cursor.limit(-1):
#    1420             return result
#    1421         return None
#
# /usr/local/lib/python3.7/dist-packages/pymongo/cursor.py in next(self)
#    1246         if self.__empty:
#    1247             raise StopIteration
# -> 1248         if len(self.__data) or self._refresh():
#    1249             return self.__data.popleft()
#    1250         else:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/cursor.py in _refresh(self)
#    1137
#    1138         if not self.__session:
# -> 1139             self.__session = self.__collection.database.client._ensure_session()
#    1140
#    1141         if self.__id is None:  # Query
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1661             # Don't make implicit sessions causally consistent. Applications
#    1662             # should always opt-in.
# -> 1663             return self.__start_session(True, causal_consistency=False)
#    1664         except (ConfigurationError, InvalidOperation):
#    1665             # Sessions not supported.
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1606         # Raises ConfigurationError if sessions are not supported.
#    1607         if implicit:
# -> 1608             self._topology._check_implicit_session_support()
#    1609             server_session = _EmptyServerSession()
#    1610         else:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/topology.py in _check_implicit_session_support(self)
#     517     def _check_implicit_session_support(self):
#     518         with self._lock:
# --> 519             self._check_session_support()
#     520
#     521     def _check_session_support(self):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/topology.py in _check_session_support(self)
#     534             elif not self._description.readable_servers:
#     535                 self._select_servers_loop(
# --> 536                     readable_server_selector, self._settings.server_selection_timeout, None
#     537                 )
#     538
#
# /usr/local/lib/python3.7/dist-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     237             # came after our most recent apply_selector call, since we've
#     238             # held the lock until now.
# --> 239             self._condition.wait(common.MIN_HEARTBEAT_INTERVAL)
#     240             self._description.check_compatible()
#     241             now = time.monotonic()
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Create

# %% [markdown]
# ## Read

# %% [markdown]
# ## Update

# %% [markdown]
# ## Delete
